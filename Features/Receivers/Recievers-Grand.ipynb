# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # INSTRUCTIONS
#
# Check Before Running the Cells
#
# 1.   Check the paths to save the files (#path-check)
# 2.   Check Number of Epochs to train model (#epoch-check)
# 3.   Check whether 'pyaxmlparser' is installed or not. If not then install it as per instructions provided in cell below

# %% [markdown]
# # DATASET PREPARATION

# %%
# If pyaxmlparser is not present, run the following command--
# !pip install pyaxmlparser
# Out:
# Collecting pyaxmlparser
#   Downloading https://files.pythonhosted.org/packages/4e/30/5d6562995efb33dada335b5f02c61562ff91f36b8d746ad528e9e348bf9f/pyaxmlparser-0.3.24-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 8.2MB/s
# Requirement already satisfied: click>=6.7 in /usr/local/lib/python3.7/dist-packages (from pyaxmlparser) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pyaxmlparser) (4.2.6)
# Installing collected packages: pyaxmlparser
# Successfully installed pyaxmlparser-0.3.24

# %%
import os
from pyaxmlparser import APK

# %%
def process(arr1):
  res = []
  for i in arr1:
    temp = i.split('.')
    if 'service' in temp:
      ind = temp.index('service')
      res.append(".".join(temp[ind:]))
    elif 'intent' in temp:
      ind = temp.index('intent')
      res.append(".".join(temp[ind:]))
    else:
      res.append(i.split(".")[-1])
  return res

# %%
#path-check

#Malware Files
malware_count = 0
recievers = []
for entry in os.scandir("/content/drive/MyDrive/Project BE 2020-2021/Datasets/ZenodoMerged/"):
    if malware_count == 100:
        break
    try:    
        if entry.path.endswith(".apk") and entry.is_file():
            a = APK(entry.path)
            recievers.append(process(a.get_receivers()))
            malware_count += 1
            print(malware_count)         
    except:
        print(entry.path)

print(recievers)
# Out:
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 1
# 2
# 3
# 4
# 5
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 6
# 7
# 8
# 9
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 10
# 11
# 12
# 13
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 14
# 15
# 16
# 17
# 18
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 19
# 20
# 21
# 22
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 23
# 24
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 25
# 26
# 27
# 28
# 29
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 30
# 31
# 32
# 33
# 34
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 35
# 36
# 37
# 38
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 39
# 40
# 41
# 42
# 43
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 44
# 45
# 46
# 47
# 48
# 49
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 50
# 51
# 52
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 53
# 54
# 55
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 56
# 57
# 58
# 59
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 60
# 61
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 62
# 63
# 64
# 65
# 66
# 67
# ...
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 79
# 80
# 81
# 82
# 83
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 91
# 92
# 93
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 94
# 95
# 96
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 97
# 98
# 99
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 100
# [['DisplayCheckRebootReceiver', 'Tracker'], ['BootReceiver'], ['BootReceiver', 'GCMBroadcastReceiver'], ['BootReceiver'], ['ReferrerReceiver'], ['AdNotification', 'BootReceiverLeadBolt', 'AdNotification', 'BootReceiverLeadBolt2', 'UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['BootReceiver', 'BootReceiver', 'WidgetClass', 'BootReceiver'], ['GCMBroadcastReceiver'], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BillingReceiver', 'Processor'], ['LocationReceiver', 'FinderReceiver', 'BootReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], [], ['ReEngagement', 'BootReceiver', 'AdNotification'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['service.AutoStartReceiver', 'BootReceiver', 'BootReceiver', 'AdNotification', 'AdIcon'], [], [], ['BootReceiver'], ['BaseBBR'], [], ['BootReceiver'], ['BootReceiver', 'WidgetClass', 'ReferrerReceiver', 'AdNotification', 'AdReminderNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['PackageBroascastReceiver'], [], ['HoroscopeWidget', 'HoroscopeBoot', 'AdNotification', 'BootReceiver'], [], ['BootReceiver', 'AdNotification', 'AdReminderNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['AnalyticsReceiver', 'ShutdownReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['Boot', 'YoumiReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'service.StartAtBootServiceReceiver', 'AutoSoundDisablerWidgetProvider'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BootStartReceiver'], ['GCMBroadcastReceiver'], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver', 'YoumiReceiver'], ['WosdRzsen', 'BxlryActivity', 'CusleyActivity', 'CoseSooxty', 'TsinVsen'], ['GCMBroadcastReceiver'], ['BootCompletedReceiver', 'InstallReceiver'], [], [], ['GCMBroadcastReceiver'], ['StartupReciver'], ['AnalyticsReceiver', 'ShutdownReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['HoroscopeWidget', 'HoroscopeBoot', 'AdNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['GCMBroadcastReceiver'], ['InstallationTracker'], ['GCMBroadcastReceiver'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['DeliveryReceiver', 'MessageReceiver', 'BootReceiver'], [], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], [], ['BootReceiver', 'AdNotification'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['BootReceiver'], [], ['BootReceiver'], ['AdNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['AdsReceiver'], ['BootReceiver'], [], ['FtpWidget'], ['GCMBroadcastReceiver'], ['ReceiverCallForward', 'ReceiverSms', 'ReceiverCheckSub', 'ReceiverBoot', 'AdminReceiver', 'ReceiverDataSms', 'OpenApp'], ['TransactionPushReceive', 'TransactionPushReceive', 'TransactionPushReceive', 'TransactionBroadCastReceiver', 'DataBaseReceiver'], ['GCMBroadcastReceiver'], ['Widget_4x1', 'Widget_4x2', 'BootReceiver'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['GCMBroadcastReceiver'], ['ReferrerReceiver', 'BootReceiver'], ['AdPushReceiver']]

# %%
#path-check

#Benign Files
benign_count = 0
for entry in os.scandir("/content/drive/MyDrive/Project BE 2020-2021/Datasets/Benign_2015_2016_2017/"):
    if benign_count == 100:
        break
    try:    
        if entry.path.endswith(".apk") and entry.is_file():
            a = APK(entry.path)
            recievers.append(process(a.get_receivers()))
            benign_count += 1
            print(benign_count)
    except:
        print(entry.path)
        
print(recievers)
# Out:
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 1
# 2
# 3
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 4
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 5
# 6
# 7
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 8
# 9
# 10
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 11
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 12
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 13
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 14
# 15
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 16
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 17
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 18
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 19
# 20
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 21
# 22
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 23
# Failed to get the attribute with namespace
# 24
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 25
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 26
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 27
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 28
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 29
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 30
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 31
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 32
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 33
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 34
# Name 'android:versionName' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:minSdkVersion' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:targetSdkVersion' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:required' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:protectionLevel' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:glEsVersion' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:required' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:theme' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:label' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:icon' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:description' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:allowBackup' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:logo' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:supportsRtl' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:protectionLevel' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:authorities' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:permission' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:parentActivityName' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:protectionLevel' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:windowSoftInputMode' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:scheme' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:host' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:parentActivityName' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:parentActivityName' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:autoVerify' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:scheme' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:host' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:pathPattern' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:windowSoftInputMode' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:theme' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:launchMode' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:resource' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:theme' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:launchMode' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:resource' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:windowSoftInputMode' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:hardwareAccelerated' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:screenOrientation' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:configChanges' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:enabled' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:authorities' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:enabled' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:authorities' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:authorities' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:syncable' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:protectionLevel' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:protectionLevel' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:value' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:protectionLevel' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:protectionLevel' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:name' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# Name 'android:exported' starts with 'android:' prefix! The Manifest seems to be broken? Removing prefix.
# ...
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 80
# 81
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 82
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 83
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 84
# 85
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 86
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 87
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 88
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 89
# 90
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 91
# 92
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 93
# 94
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 95
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 96
# 97
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 98
# 99
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# 100
# [['DisplayCheckRebootReceiver', 'Tracker'], ['BootReceiver'], ['BootReceiver', 'GCMBroadcastReceiver'], ['BootReceiver'], ['ReferrerReceiver'], ['AdNotification', 'BootReceiverLeadBolt', 'AdNotification', 'BootReceiverLeadBolt2', 'UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['BootReceiver', 'BootReceiver', 'WidgetClass', 'BootReceiver'], ['GCMBroadcastReceiver'], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BillingReceiver', 'Processor'], ['LocationReceiver', 'FinderReceiver', 'BootReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], [], ['ReEngagement', 'BootReceiver', 'AdNotification'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['service.AutoStartReceiver', 'BootReceiver', 'BootReceiver', 'AdNotification', 'AdIcon'], [], [], ['BootReceiver'], ['BaseBBR'], [], ['BootReceiver'], ['BootReceiver', 'WidgetClass', 'ReferrerReceiver', 'AdNotification', 'AdReminderNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['PackageBroascastReceiver'], [], ['HoroscopeWidget', 'HoroscopeBoot', 'AdNotification', 'BootReceiver'], [], ['BootReceiver', 'AdNotification', 'AdReminderNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['AnalyticsReceiver', 'ShutdownReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['Boot', 'YoumiReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'service.StartAtBootServiceReceiver', 'AutoSoundDisablerWidgetProvider'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BootStartReceiver'], ['GCMBroadcastReceiver'], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver', 'YoumiReceiver'], ['WosdRzsen', 'BxlryActivity', 'CusleyActivity', 'CoseSooxty', 'TsinVsen'], ['GCMBroadcastReceiver'], ['BootCompletedReceiver', 'InstallReceiver'], [], [], ['GCMBroadcastReceiver'], ['StartupReciver'], ['AnalyticsReceiver', 'ShutdownReceiver'], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], ['HoroscopeWidget', 'HoroscopeBoot', 'AdNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['GCMBroadcastReceiver'], ['BootReceiver'], ['GCMBroadcastReceiver'], ['InstallationTracker'], ['GCMBroadcastReceiver'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['DeliveryReceiver', 'MessageReceiver', 'BootReceiver'], [], [], ['GCMBroadcastReceiver'], ['GCMBroadcastReceiver'], [], ['BootReceiver', 'AdNotification'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['BootReceiver'], [], ['BootReceiver'], ['AdNotification', 'BootReceiver'], ['GCMBroadcastReceiver'], ['AdsReceiver'], ['BootReceiver'], [], ['FtpWidget'], ['GCMBroadcastReceiver'], ['ReceiverCallForward', 'ReceiverSms', 'ReceiverCheckSub', 'ReceiverBoot', 'AdminReceiver', 'ReceiverDataSms', 'OpenApp'], ['TransactionPushReceive', 'TransactionPushReceive', 'TransactionPushReceive', 'TransactionBroadCastReceiver', 'DataBaseReceiver'], ['GCMBroadcastReceiver'], ['Widget_4x1', 'Widget_4x2', 'BootReceiver'], ['UserDetailsReceiver', 'MessageReceiver', 'DeliveryReceiver', 'BootReceiver'], ['GCMBroadcastReceiver'], ['ReferrerReceiver', 'BootReceiver'], ['AdPushReceiver'], ['FirebaseInstanceIdReceiver', 'FirebaseInstanceIdInternalReceiver', 'AppMeasurementReceiver'], ['MusicWidgetProvider', 'MusicIntentReceiver'], ['ApsalarReceiver', 'NotificationBroadcastReceiver', 'LocalNotificationReceiver', 'ReferrerReceiver', 'GCMBroadcastReceiver', 'GcmBroadcastReceiver', 'ReferrerCatcher'], ['AnalyticsReceiver', 'GcmBroadcastReceiver', 'MultipleInstallBroadcastReceiver', 'ReferrerReceiver', 'InstallReferrerReceiver', 'StreakAlarm', 'TokenRefreshAlarm', 'AutoTokenRefreshAlarm', 'AppMeasurementReceiver'], ['gcmBroadcastReceiver', 'VKPaymentsReceiver', 'remBroadcastReceiver', 'CampaignTrackingReceiver'], ['StartAppAtB ...

# %%
full_list1 = []
for i in recievers:
    full_list1.extend(i)
full_list1

# %%
from collections import Counter

# %%
countingServices = dict(Counter(full_list1))
countingServices

# %%
removable = []
for i in countingServices.keys():
    if countingServices[i] < 10:
        removable.append(i)
removable

# %%
for i in recievers:
    for j in removable:
        try:
            i.remove(j)
        except ValueError:
            pass
recievers

# %%
allPermissions = set()
for i in recievers:
    allPermissions = allPermissions.union(set(i))
print(allPermissions)
# Out:
# {'ReceiverCallForward', 'ReceiverSms', 'LocalPushReceiver', 'InstallReceiver', 'AlarmManagerBroadcastReceiver', 'SecurityDeviceAdminReceiver', 'CallHandler', 'FirebaseInstanceIdReceiver', 'OurAlarmReceiver', 'TimeSetReceiver', 'ShutdownReceiver', 'WearableDispatcherBroadcastReceiver', 'AlarmBroadcastReceiver', 'IntentReceiver', 'GCMHandler', 'BillingReceiver', 'TaskWidget', 'TextMeAppWidgetProvider_resizable', 'BatteryProfiler$StartStopReceiver', 'MMSReceiver', 'gcmBroadcastReceiver', 'AudioWidget', 'remBroadcastReceiver', 'ReminderNotificationActionReceiver', 'StopServiceBroadcastReceiver', 'TokenRefreshAlarm', 'AvabelBroadcastReceiver', 'PackageBroascastReceiver', 'TextMeAppWidgetProvider_2x1', 'PlacesInfoProfiler$GeofenceEventBroadcastReceiver', 'service.receivers.PingReceiver', 'SnoozeTestReceiver', 'FlashlightWidgetProvider1x1', 'AdPushReceiver', 'PackageChangeListener', 'OutgoingCallBroadcastReceiver', 'WosdRzsen', 'PhotoWidget', 'BaseBBR', 'LockBroadcastReceiver', 'WidgetProvider', 'HoroscopeWidget', 'CloseAppBroadcastReceiver', 'WidgetProviderWeek', 'AppBroadcastReceiver', 'CoreReceiver', 'PlayReceiver', 'AppMeasurementReceiver', 'SystemStartupBroadcastReceiver', 'InstallReferrer', 'StatusBarBroadcastReceiver', 'BluetoothManager', 'ReceiverDataSms', 'TransactionPushReceive', 'GCMBroadcastReceiver', 'UnreadStartReceiver', 'MaintenanceReceiver', 'AnagogPlacesProfiler$StartStopReceiver', 'OpenApp', 'MusicWidgetProvider', 'JAlarmReceiver', 'JExMediaScanerAlertReceiver', 'PlacesInfoProfiler$WifiScanResultsReceiver', 'NotiBrokerReciever', 'PlacesProfiler$LocationReceiver', 'service.AlarmReceiver', 'VendingInstallReferrerReceiver', 'MediaButtonIntentReceiver', 'service.DeviceStateReceiver', 'UserDetailsReceiver', 'ProfilersReactivator', 'PhoneStateChangedReceiver', 'CityTracker', 'ResultsUploaderService$Stopper', 'OpenNotificationBroadcastReceiver', 'AlarmReceiver', 'BizCalReceiver', 'AdIcon', 'GCMReceiver', 'PushReceiver', 'NetworkManager', 'ReferrerHandler', 'ACKSendBroadcastReceiver', 'ReferrerReceiver', 'SMSDeliveredReceiver', 'DataBaseReceiver', 'AdjustReferrerReceiver', 'PushServiceReceiver', 'AnagogPlacesProfiler$LocationsReceiver', 'LocationReceiver', 'KeepAliveHandler', 'HomeProfiler$SignificantMotionReceiver', 'WidgetProviderDayPro', 'DummySmsReceiver', 'PMWidgetProvider', 'ResponseReceiver', 'WidgetProviderAgenda', 'GcmReceiver', 'GoogleCloudMessagingBroadcastReceiver', 'service.StartOnBoot', 'IncomingSmsReceiver', 'ReceiverInstall', 'TransactionBroadCastReceiver', 'SignificantMotionTestProfiler$SignificantMotionReceiver', 'ReceiverChargeState', 'SMSReceiver', 'WidgetProviderIcon', 'SignupNotificationReminder', 'NetworkStateReceiver', 'SoundWidgetProvider', 'PlacesInfoProfiler$PressureSensorAlarmReceiver', 'LaunchNotificationReceiver', 'CopyBroadcastReceiver', 'ImIdShareBroadCastReceiver', 'AlarmReceiver1', 'CampaignTrackingReceiver', 'service.StartAtBootServiceReceiver', 'PowerConnectionReceiver', 'TriggerReceiver', 'NetworkMonitor', 'BroadcastReceiverConnectionChange', 'ReminderReceiver', 'AutostartReceiver', 'AnagogPlacesProfiler$LocationsRetriever', 'Widget_4x2', 'DummyMmsReceiver', 'ReferralReceiver', 'RestoreReceiver', 'TextMeAppWidgetProvider_3x1', 'ZendeskDeepLinkingBroadcastReceiver', 'NotificationReceiver', 'C2DMRegistrationReceiver', 'BootCompleteReceiver', 'RegisterUponInstallReceiver', 'NetworkStatusReceiver', 'MessageReceiver', 'VKPaymentsReceiver', 'WifiMonitorReceiver', 'LoggingToastReceiver', 'Receiver', 'service.receivers.NetworkStatusReceiver', 'OngoingNotificationReceiver', 'UpgradeReceiver', 'DaemonHelperReceiver', 'AdReminderNotification', 'WidgetPhotoProvider', 'MyReferrerCatcher', 'HomeProfiler$SignificantMotionPollingAlarmReceiver', 'LargeTripItAppWidget', 'RocqCampaignReceiver', 'PackageMonitorReceiver', 'HomeProfiler$StartStopReceiver', 'ReceiverBoot', 'TwInstallReferrerReceiver', 'VideoIntentReceiver', 'NotificationClearReceiver', 'BootReceiver', 'FinderReceiver', 'PlacesInfoProfiler$Sta ...

# %%
print(len(allPermissions))

allPermissions = list(allPermissions)
# Out:
# 293

# %%
rowList = []
for i in range(len(recievers)):
    x = []
    for j in range(len(allPermissions)):
        x.append(0)
    rowList.append(x)

# %%
for i in range(len(recievers)):
    for j in recievers[i]:
        x = allPermissions.index(j)
        if x > -1:
            rowList[i][x] = 1

# %%
print(len(rowList))
# Out:
# 200

# %%
allPermissions.append('class')
for i in range(0, malware_count):
    rowList[i].append(1)
while(True):
    i += 1
    if i == len(rowList):
        break
    rowList[i].append(0)

# %%
print(allPermissions)
# Out:
# ['ReceiverCallForward', 'ReceiverSms', 'LocalPushReceiver', 'InstallReceiver', 'AlarmManagerBroadcastReceiver', 'SecurityDeviceAdminReceiver', 'CallHandler', 'FirebaseInstanceIdReceiver', 'OurAlarmReceiver', 'TimeSetReceiver', 'ShutdownReceiver', 'WearableDispatcherBroadcastReceiver', 'AlarmBroadcastReceiver', 'IntentReceiver', 'GCMHandler', 'BillingReceiver', 'TaskWidget', 'TextMeAppWidgetProvider_resizable', 'BatteryProfiler$StartStopReceiver', 'MMSReceiver', 'gcmBroadcastReceiver', 'AudioWidget', 'remBroadcastReceiver', 'ReminderNotificationActionReceiver', 'StopServiceBroadcastReceiver', 'TokenRefreshAlarm', 'AvabelBroadcastReceiver', 'PackageBroascastReceiver', 'TextMeAppWidgetProvider_2x1', 'PlacesInfoProfiler$GeofenceEventBroadcastReceiver', 'service.receivers.PingReceiver', 'SnoozeTestReceiver', 'FlashlightWidgetProvider1x1', 'AdPushReceiver', 'PackageChangeListener', 'OutgoingCallBroadcastReceiver', 'WosdRzsen', 'PhotoWidget', 'BaseBBR', 'LockBroadcastReceiver', 'WidgetProvider', 'HoroscopeWidget', 'CloseAppBroadcastReceiver', 'WidgetProviderWeek', 'AppBroadcastReceiver', 'CoreReceiver', 'PlayReceiver', 'AppMeasurementReceiver', 'SystemStartupBroadcastReceiver', 'InstallReferrer', 'StatusBarBroadcastReceiver', 'BluetoothManager', 'ReceiverDataSms', 'TransactionPushReceive', 'GCMBroadcastReceiver', 'UnreadStartReceiver', 'MaintenanceReceiver', 'AnagogPlacesProfiler$StartStopReceiver', 'OpenApp', 'MusicWidgetProvider', 'JAlarmReceiver', 'JExMediaScanerAlertReceiver', 'PlacesInfoProfiler$WifiScanResultsReceiver', 'NotiBrokerReciever', 'PlacesProfiler$LocationReceiver', 'service.AlarmReceiver', 'VendingInstallReferrerReceiver', 'MediaButtonIntentReceiver', 'service.DeviceStateReceiver', 'UserDetailsReceiver', 'ProfilersReactivator', 'PhoneStateChangedReceiver', 'CityTracker', 'ResultsUploaderService$Stopper', 'OpenNotificationBroadcastReceiver', 'AlarmReceiver', 'BizCalReceiver', 'AdIcon', 'GCMReceiver', 'PushReceiver', 'NetworkManager', 'ReferrerHandler', 'ACKSendBroadcastReceiver', 'ReferrerReceiver', 'SMSDeliveredReceiver', 'DataBaseReceiver', 'AdjustReferrerReceiver', 'PushServiceReceiver', 'AnagogPlacesProfiler$LocationsReceiver', 'LocationReceiver', 'KeepAliveHandler', 'HomeProfiler$SignificantMotionReceiver', 'WidgetProviderDayPro', 'DummySmsReceiver', 'PMWidgetProvider', 'ResponseReceiver', 'WidgetProviderAgenda', 'GcmReceiver', 'GoogleCloudMessagingBroadcastReceiver', 'service.StartOnBoot', 'IncomingSmsReceiver', 'ReceiverInstall', 'TransactionBroadCastReceiver', 'SignificantMotionTestProfiler$SignificantMotionReceiver', 'ReceiverChargeState', 'SMSReceiver', 'WidgetProviderIcon', 'SignupNotificationReminder', 'NetworkStateReceiver', 'SoundWidgetProvider', 'PlacesInfoProfiler$PressureSensorAlarmReceiver', 'LaunchNotificationReceiver', 'CopyBroadcastReceiver', 'ImIdShareBroadCastReceiver', 'AlarmReceiver1', 'CampaignTrackingReceiver', 'service.StartAtBootServiceReceiver', 'PowerConnectionReceiver', 'TriggerReceiver', 'NetworkMonitor', 'BroadcastReceiverConnectionChange', 'ReminderReceiver', 'AutostartReceiver', 'AnagogPlacesProfiler$LocationsRetriever', 'Widget_4x2', 'DummyMmsReceiver', 'ReferralReceiver', 'RestoreReceiver', 'TextMeAppWidgetProvider_3x1', 'ZendeskDeepLinkingBroadcastReceiver', 'NotificationReceiver', 'C2DMRegistrationReceiver', 'BootCompleteReceiver', 'RegisterUponInstallReceiver', 'NetworkStatusReceiver', 'MessageReceiver', 'VKPaymentsReceiver', 'WifiMonitorReceiver', 'LoggingToastReceiver', 'Receiver', 'service.receivers.NetworkStatusReceiver', 'OngoingNotificationReceiver', 'UpgradeReceiver', 'DaemonHelperReceiver', 'AdReminderNotification', 'WidgetPhotoProvider', 'MyReferrerCatcher', 'HomeProfiler$SignificantMotionPollingAlarmReceiver', 'LargeTripItAppWidget', 'RocqCampaignReceiver', 'PackageMonitorReceiver', 'HomeProfiler$StartStopReceiver', 'ReceiverBoot', 'TwInstallReferrerReceiver', 'VideoIntentReceiver', 'NotificationClearReceiver', 'BootReceiver', 'FinderReceiver', 'PlacesInfoProfiler$Sta ...

# %%
rowList.insert(0, allPermissions)

# %%
#path-check

import csv
with open('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Recievers Dataset.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(rowList)

# %%
#path-check

with open('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/ReceiverListForPrediction.txt', 'w') as f:
    f.writelines(str(allPermissions[:-1]))

# %% [markdown]
# # MODEL PREPARATION

# %% [markdown]
# ## GRU MODEL

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
#path-check

df = pd.read_csv('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Recievers Dataset.csv')
df.shape
# Out:
# (11975, 594)

# %%
target = df["class"]
df = df.drop(columns="class")
X_train_full, X_test, y_train_full, y_test = train_test_split(df, target)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full)

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
regressor = Sequential()
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 593, 50)           10400
# _________________________________________________________________
# dropout (Dropout)            (None, 593, 50)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 593, 50)           20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 593, 50)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 593, 50)           20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 593, 50)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')

# %%
#epoch-check
#path-check

regressor.fit(X_train,y_train,epochs=500,batch_size=32)
regressor.save('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Receivers_Model_500ep.hdf5')
# Out:
# Epoch 1/500
#   8/211 [>.............................] - ETA: 19s - loss: 0.4657
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7f0a14efbfb3> in <module>()
#       2 #path-check
#       3
# ----> 4 regressor.fit(X_train,y_train,epochs=500,batch_size=32)
#       5 regressor.save('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Receivers_Model_500ep.hdf5')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## LSTM MODEL

# %%
from __future__ import print_function
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
np.random.seed(1337)  # for reproducibility
from keras.utils import np_utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Embedding
from keras.layers import LSTM, SimpleRNN, GRU
from keras.datasets import imdb
from keras.utils.np_utils import to_categorical
from sklearn.metrics import (precision_score, recall_score,f1_score, accuracy_score,mean_squared_error,mean_absolute_error)
from sklearn import metrics
from sklearn.preprocessing import Normalizer
import h5py
from keras import callbacks
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger

# %%
#path-check

traindata = pd.read_csv('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Recievers Dataset.csv')
testdata = pd.read_csv('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Recievers Dataset.csv')

# %%
traindata.shape
# Out:
# (11975, 594)

# %%
X = traindata.iloc[1:,0:(traindata.shape[1]-1)]
Y = traindata.iloc[1:,(traindata.shape[1]-1)]
C = testdata.iloc[1:,(traindata.shape[1]-1)]
T = testdata.iloc[1:,0:(traindata.shape[1]-1)]

# %%
scaler = Normalizer().fit(X)
trainX = scaler.transform(X)
np.set_printoptions(precision=3)

# %%
scaler = Normalizer().fit(T)
testT = scaler.transform(T)
np.set_printoptions(precision=3)

# %%
y_train = np.array(Y)
y_test = np.array(C)

# %%
X_train = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
X_test = np.reshape(testT, (testT.shape[0], 1, testT.shape[1]))

# %%
batch_size = 32

# %%
model = Sequential()
model.add(LSTM(64,input_dim=(traindata.shape[1]-1), return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(64, return_sequences=True)) 
model.add(Dropout(0.1))
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.1))
model.add(Dense(1))
model.add(Activation('softmax'))

# %%
#epoch-check
#path-check

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=batch_size, epochs=500, validation_data=(X_test, y_test))
model.save("/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Receivers_Model_LSTM_500ep_softmax.hdf5")
# Out:
# Epoch 1/500
# 375/375 [==============================] - 12s 15ms/step - loss: 0.2805 - accuracy: 0.4984 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 2/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2734 - accuracy: 0.5025 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 3/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2693 - accuracy: 0.4977 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 4/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2681 - accuracy: 0.5036 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 5/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2717 - accuracy: 0.4950 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 6/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2682 - accuracy: 0.4967 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 7/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2709 - accuracy: 0.5037 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 8/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2703 - accuracy: 0.4991 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 9/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2719 - accuracy: 0.4976 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 10/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2672 - accuracy: 0.4996 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 11/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2668 - accuracy: 0.5069 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 12/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2732 - accuracy: 0.5100 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 13/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2734 - accuracy: 0.5016 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 14/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2665 - accuracy: 0.5081 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 15/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2664 - accuracy: 0.4987 - val_loss: 0.2693 - val_accuracy: 0.5010
# Epoch 16/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2685 - accuracy: 0.4976 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 17/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2712 - accuracy: 0.5004 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 18/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2690 - accuracy: 0.4947 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 19/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2646 - accuracy: 0.5088 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 20/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2650 - accuracy: 0.4959 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 21/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2699 - accuracy: 0.5079 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 22/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2743 - accuracy: 0.4876 - val_loss: 0.2697 - val_accuracy: 0.5010
# Epoch 23/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2764 - accuracy: 0.4992 - val_loss: 0.2694 - val_accuracy: 0.5010
# Epoch 24/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2654 - accuracy: 0.4965 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 25/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2659 - accuracy: 0.5050 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 26/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2674 - accuracy: 0.5035 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 27/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2671 - accuracy: 0.5027 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 28/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2653 - accuracy: 0.5027 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 29/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2704 - accuracy: 0.5062 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 30/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2792 - accuracy: 0.4996 - val_loss: 0.2697 - val_accuracy: 0.5010
# Epoch 31/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2761 - accuracy: 0.4987 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 32/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2693 - accuracy: 0.4951 - val_loss: 0.2700 - val_accuracy: 0.5010
# Epoch 33/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2654 - accuracy: 0.5024 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 34/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2678 - accuracy: 0.4969 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 35/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2699 - accuracy: 0.5061 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 36/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2769 - accuracy: 0.4971 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 37/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2706 - accuracy: 0.4993 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 38/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2692 - accuracy: 0.5029 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 39/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2713 - accuracy: 0.5043 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 40/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2762 - accuracy: 0.5009 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 41/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2678 - accuracy: 0.5016 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 42/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2678 - accuracy: 0.5006 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 43/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2689 - accuracy: 0.5082 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 44/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2630 - accuracy: 0.5016 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 45/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2700 - accuracy: 0.5004 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 46/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2687 - accuracy: 0.4981 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 47/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2623 - accuracy: 0.5120 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 48/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2743 - accuracy: 0.4996 - val_loss: 0.2692 - val_accuracy: 0.5010
# Epoch 49/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2654 - accuracy: 0.4977 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 50/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2690 - accuracy: 0.4958 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 51/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2712 - accuracy: 0.4990 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 52/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2759 - accuracy: 0.5015 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 53/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2662 - accuracy: 0.5024 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 54/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2694 - accuracy: 0.4968 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 55/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2698 - accuracy: 0.5025 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 56/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2655 - accuracy: 0.5076 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 57/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2651 - accuracy: 0.5022 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 58/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2709 - accuracy: 0.5031 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 59/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2624 - accuracy: 0.5022 - val_loss: 0.2694 - val_accuracy: 0.5010
# Epoch 60/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2685 - accuracy: 0.5050 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 61/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2703 - accuracy: 0.5031 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 62/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2667 - accuracy: 0.4975 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 63/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2655 - accuracy: 0.4990 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 64/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2645 - accuracy: 0.5088 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 65/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2735 - accuracy: 0.5051 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 66/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2681 - accuracy: 0.5044 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 67/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2681 - accuracy: 0.4967 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 68/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2678 - accuracy: 0.4990 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 69/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2663 - accuracy: 0.4997 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 70/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2709 - accuracy: 0.4962 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 71/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2656 - accuracy: 0.5062 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 72/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2681 - accuracy: 0.5015 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 73/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2743 - accuracy: 0.5007 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 74/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2658 - accuracy: 0.4997 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 75/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2770 - accuracy: 0.5029 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 76/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2686 - accuracy: 0.5056 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 77/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2699 - accuracy: 0.4999 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 78/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2727 - accuracy: 0.5033 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 79/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2684 - accuracy: 0.4945 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 80/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2639 - accuracy: 0.5063 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 81/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2630 - accuracy: 0.4994 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 82/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2698 - accuracy: 0.5027 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 83/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2719 - accuracy: 0.4979 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 84/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2672 - accuracy: 0.4922 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 85/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2729 - accuracy: 0.5042 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 86/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2741 - accuracy: 0.5030 - val_loss: 0.2693 - val_accuracy: 0.5010
# Epoch 87/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2711 - accuracy: 0.4997 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 88/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2684 - accuracy: 0.4969 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 89/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2698 - accuracy: 0.4976 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 90/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2652 - accuracy: 0.5006 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 91/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2800 - accuracy: 0.5029 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 92/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2705 - accuracy: 0.5045 - val_loss: 0.2696 - val_accuracy: 0.5010
# Epoch 93/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2694 - accuracy: 0.5069 - val_loss: 0.2693 - val_accuracy: 0.5010
# Epoch 94/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2724 - accuracy: 0.5022 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 95/500
# 375/375 [==============================] - 5s 13ms/step - loss: 0.2686 - accuracy: 0.5028 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 96/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2700 - accuracy: 0.4989 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 97/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2701 - accuracy: 0.5061 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 98/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2710 - accuracy: 0.5000 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 99/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2623 - accuracy: 0.4945 - val_loss: 0.2692 - val_accuracy: 0.5010
# Epoch 100/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2697 - accuracy: 0.4966 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 101/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2696 - accuracy: 0.5039 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 102/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2675 - accuracy: 0.4987 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 103/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2651 - accuracy: 0.4994 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 104/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2734 - accuracy: 0.4960 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 105/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2630 - accuracy: 0.4994 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 106/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2740 - accuracy: 0.4974 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 107/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2699 - accuracy: 0.4994 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 108/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2656 - accuracy: 0.4992 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 109/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2709 - accuracy: 0.4949 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 110/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2667 - accuracy: 0.5021 - val_loss: 0.2714 - val_accuracy: 0.5010
# Epoch 111/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2747 - accuracy: 0.5023 - val_loss: 0.2699 - val_accuracy: 0.5010
# Epoch 112/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2676 - accuracy: 0.4950 - val_loss: 0.2693 - val_accuracy: 0.5010
# Epoch 113/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2683 - accuracy: 0.5103 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 114/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2641 - accuracy: 0.4938 - val_loss: 0.2693 - val_accuracy: 0.5010
# Epoch 115/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2759 - accuracy: 0.4975 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 116/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2768 - accuracy: 0.4965 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 117/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2725 - accuracy: 0.5095 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 118/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2725 - accuracy: 0.5014 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 119/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2663 - accuracy: 0.5002 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 120/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2651 - accuracy: 0.4945 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 121/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2695 - accuracy: 0.4998 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 122/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2692 - accuracy: 0.5069 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 123/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2764 - accuracy: 0.4994 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 124/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2694 - accuracy: 0.5007 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 125/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2721 - accuracy: 0.4929 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 126/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2686 - accuracy: 0.5030 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 127/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2663 - accuracy: 0.5053 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 128/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2771 - accuracy: 0.4994 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 129/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2673 - accuracy: 0.5010 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 130/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2706 - accuracy: 0.5024 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 131/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2679 - accuracy: 0.4948 - val_loss: 0.2691 - val_accuracy: 0.5010
# Epoch 132/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2695 - accuracy: 0.5012 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 133/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2684 - accuracy: 0.5073 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 134/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2705 - accuracy: 0.5045 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 135/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2701 - accuracy: 0.5048 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 136/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2691 - accuracy: 0.5094 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 137/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2699 - accuracy: 0.4969 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 138/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2713 - accuracy: 0.5048 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 139/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2691 - accuracy: 0.5009 - val_loss: 0.2696 - val_accuracy: 0.5010
# Epoch 140/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2673 - accuracy: 0.5003 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 141/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2734 - accuracy: 0.5018 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 142/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2722 - accuracy: 0.4965 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 143/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2722 - accuracy: 0.4958 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 144/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2704 - accuracy: 0.4956 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 145/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2678 - accuracy: 0.5022 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 146/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2686 - accuracy: 0.5018 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 147/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2688 - accuracy: 0.5062 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 148/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2700 - accuracy: 0.5091 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 149/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2686 - accuracy: 0.5003 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 150/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2668 - accuracy: 0.5031 - val_loss: 0.2697 - val_accuracy: 0.5010
# Epoch 151/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2731 - accuracy: 0.5015 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 152/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2700 - accuracy: 0.5060 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 153/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2758 - accuracy: 0.4981 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 154/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2678 - accuracy: 0.4993 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 155/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2774 - accuracy: 0.5020 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 156/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2718 - accuracy: 0.5061 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 157/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2779 - accuracy: 0.5003 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 158/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2692 - accuracy: 0.4952 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 159/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2695 - accuracy: 0.4969 - val_loss: 0.2692 - val_accuracy: 0.5010
# Epoch 160/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2713 - accuracy: 0.5081 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 161/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2644 - accuracy: 0.5025 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 162/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2638 - accuracy: 0.4959 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 163/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2699 - accuracy: 0.4980 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 164/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2746 - accuracy: 0.4901 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 165/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2681 - accuracy: 0.5056 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 166/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2716 - accuracy: 0.5005 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 167/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2745 - accuracy: 0.5023 - val_loss: 0.2690 - val_accuracy: 0.5010
# Epoch 168/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2690 - accuracy: 0.4968 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 169/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2754 - accuracy: 0.4985 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 170/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2706 - accuracy: 0.5052 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 171/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2752 - accuracy: 0.5021 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 172/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2694 - accuracy: 0.5036 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 173/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2704 - accuracy: 0.4942 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 174/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2716 - accuracy: 0.5101 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 175/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2722 - accuracy: 0.4960 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 176/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2751 - accuracy: 0.5031 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 177/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2758 - accuracy: 0.5016 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 178/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2669 - accuracy: 0.4984 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 179/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2744 - accuracy: 0.4980 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 180/500
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2689 - accuracy: 0.4998 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 181/500
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2723 - accuracy: 0.5059 - val_loss: 0.2688 - val_accuracy: 0.5010
# Epoch 182/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2765 - accuracy: 0.5047 - val_loss: 0.2689 - val_accuracy: 0.5010
# Epoch 183/500
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2689 - accuracy: 0.5036 - val_loss: 0.2687 - val_accuracy: 0.5010
# Epoch 184/500
# 375/375 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.4895

# %% [markdown]
# # ACCURACY CHECK

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import load_model
import numpy as np
from sklearn.preprocessing import Normalizer

# %%
testdata = pd.read_csv('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Recievers Dataset.csv')
testdata.shape
# Out:
# (11975, 594)

# %%
C = testdata.iloc[1:,(testdata.shape[1]-1)]
T = testdata.iloc[1:,0:(testdata.shape[1]-1)]

# %%
scaler = Normalizer().fit(T)
testT = scaler.transform(T)
np.set_printoptions(precision=3)

# %%
y_test = np.array(C)
X_test = np.reshape(testT, (testT.shape[0], 1, testT.shape[1]))

# %%
# path-check

predictionModel = load_model('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Receivers_Model_LSTM.hdf5')

# %%
y_pred = predictionModel.predict_classes(X_test)
y_pred
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [1],
#        [1]], dtype=int32)

# %%
y_pred = np.reshape(y_pred, y_test.shape)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8242024386170035

# %% [markdown]
# # PREDICTION

# %%
import os
from pyaxmlparser import APK
from keras.models import load_model
import numpy as np

# %%
def process(arr1):
  res = []
  for i in arr1:
    temp = i.split('.')
    if 'service' in temp:
      ind = temp.index('service')
      res.append(".".join(temp[ind:]))
    elif 'intent' in temp:
      ind = temp.index('intent')
      res.append(".".join(temp[ind:]))
    else:
      res.append(i.split(".")[-1])
  return res

# %%
# path-check

predictionModel = load_model('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/Receivers_Model_LSTM.hdf5')

# %%
#path-check

setRecievers = []
f1 = open('/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/Receivers/ReceiverListForPrediction.txt')
temp = f1.read()
setRecievers = temp[2:-2].split("', '")
setRecievers

# %%
#path-check

appUndertest = "/content/drive/MyDrive/Project BE 2020-2021/Quarter Final/lulubox.apk"

# %%
a = APK(appUndertest)
recievers = process(a.get_receivers())
print(recievers)
# Out:
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# Failed to get the attribute with namespace
# ['AfInstallBroadcastReceiver', 'AppMeasurementReceiver', 'AppMeasurementInstallReferrerReceiver', 'NetworkListener', 'ShadowPendingReceiver', 'FirebaseInstanceIdReceiver', 'CurrentAccessTokenExpirationBroadcastReceiver']

# %%
predictionList = [0] * len(setRecievers)
for i in recievers:
    if i in setRecievers:
        predictionList[setRecievers.index(i)] = 1

# %%
pred = np.array(predictionList, ndmin=2)
pred.shape
# Out:
# (1, 593)

# %%
predictionModel.predict(np.array(predictionList, ndmin=3))
# Out:
# array([[0.999]], dtype=float32)

# %% [markdown]
# # CONCLUSION
#
# Need to add Threshold Restriction for Prediction
